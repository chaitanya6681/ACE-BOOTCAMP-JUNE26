# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitanya6681/ACE-BOOTCAMP-JUNE26/blob/main/pandas_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd
dframe=pd.read_csv('used_cars.csv')
print(dframe)
# Out:
#             Brand      Model  Year  Mileage_kmpl    Engine_CC  Horsepower  \
# 0          Toyota      Camry  2001     19.615852  1396.560379         NaN
# 1         Hyundai        i20  2012     19.478608  1130.771005  137.021719
# 2        Mahindra     Bolero  2008     17.469920  1766.466250  142.902960
# 3             BMW         X1  2015     21.295421          NaN   49.782079
# 4           Honda      Civic  2022     18.326833  1239.334935  121.505993
# ...           ...        ...   ...           ...          ...         ...
# 1004995    Nissan    Magnite  2022     12.256422  1773.657889  117.574596
# 1004996     Honda      Amaze  2005           NaN  1705.773023   99.643689
# 1004997     Skoda    Octavia  2018     21.665335  1447.159515         NaN
# 1004998       BMW         X3  2010     17.852635  2179.906631         NaN
# 1004999      Ford  Endeavour  2010     20.839002   800.000000   11.857082
#
#         Fuel_Type Transmission Owner_Type  Color       City  Kms_Driven  \
# ...

# %%
print(dframe.head())
# Out:
#       Brand   Model  Year  Mileage_kmpl    Engine_CC  Horsepower Fuel_Type  \
# 0    Toyota   Camry  2001     19.615852  1396.560379         NaN    Hybrid
# 1   Hyundai     i20  2012     19.478608  1130.771005  137.021719    Petrol
# 2  Mahindra  Bolero  2008     17.469920  1766.466250  142.902960       NaN
# 3       BMW      X1  2015     21.295421          NaN   49.782079       NaN
# 4     Honda   Civic  2022     18.326833  1239.334935  121.505993    Diesel
#
#   Transmission Owner_Type  Color     City  Kms_Driven  Insurance_Valid  \
# 0    Automatic      First   Grey  Chennai      500928                1
# 1          NaN      First   Grey   Mumbai      211510                0
# 2    Automatic      First  Black  Kolkata      333999                1
# 3       Manual      First  White     Pune      225930                1
# 4       Manual     Second  White  Kolkata       43404                1
#
#    Service_History  Accidents  Tax_Paid  Number_of_Doors  Seats  \
# ...

# %%
print(dframe.head(10))
# Out:
#         Brand   Model  Year  Mileage_kmpl    Engine_CC  Horsepower Fuel_Type  \
# 0      Toyota   Camry  2001     19.615852  1396.560379         NaN    Hybrid
# 1     Hyundai     i20  2012     19.478608  1130.771005  137.021719    Petrol
# 2    Mahindra  Bolero  2008     17.469920  1766.466250  142.902960       NaN
# 3         BMW      X1  2015     21.295421          NaN   49.782079       NaN
# 4       Honda   Civic  2022     18.326833  1239.334935  121.505993    Diesel
# 5      Toyota   Camry  2007           NaN  1513.157430  100.927306    Petrol
# 6     Hyundai     i20  2014     16.328654  1398.722600  111.846497    Diesel
# 7     Hyundai   Creta  2001     21.895120   800.000000    0.709766    Petrol
# 8  Volkswagen  Taigun  2020     17.461847  1397.891768  104.095168    Diesel
# 9        Audi      A4  2009     12.062221  1618.723936   86.071024    Petrol
#
#   Transmission Owner_Type  Color       City  Kms_Driven  Insurance_Valid  \
# ...

# %%
dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005000 entries, 0 to 1004999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Brand             1005000 non-null  object
#  1   Model             1005000 non-null  object
#  2   Year              1005000 non-null  int64
#  3   Mileage_kmpl      924610 non-null   float64
#  4   Engine_CC         924597 non-null   float64
#  5   Horsepower        924597 non-null   float64
#  6   Fuel_Type         926267 non-null   object
#  7   Transmission      924615 non-null   object
#  8   Owner_Type        1005000 non-null  object
#  9   Color             924581 non-null   object
#  10  City              924570 non-null   object
#  11  Kms_Driven        1005000 non-null  int64
#  12  Insurance_Valid   1005000 non-null  int64
#  13  Service_History   1005000 non-null  int64
#  14  Accidents         1005000 non-null  int64
# ...

# %%
dframe.iloc[1:,2]
# Out:
# 1          2012
# 2          2008
# 3          2015
# 4          2022
# 5          2007
#            ...
# 1004995    2022
# 1004996    2005
# 1004997    2018
# 1004998    2010
# 1004999    2010
# Name: Year, Length: 1004999, dtype: int64

# %%
dframe.iloc[2:5,[0,9,1,2,5]]
# Out:
#       Brand  Color   Model  Year  Horsepower
# 2  Mahindra  Black  Bolero  2008  142.902960
# 3       BMW  White      X1  2015   49.782079
# 4     Honda  White   Civic  2022  121.505993

# %%
dframe.set_index("Model",inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2681/4020054120.py in <cell line: 0>()
# ----> 1 dframe.set_index("Model",inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['Model'] are in the columns"

# %%
dframe.loc('Model')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     575         try:
# --> 576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
#
# KeyError: 'Model'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_823/222697174.py in <cell line: 0>()
# ----> 1 dframe.loc('Model')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __call__(self, axis)
#     736
#     737         if axis is not None:
# --> 738             axis_int_none = self.obj._get_axis_number(axis)
#     739         else:
#     740             axis_int_none = axis
#
# ...

# %%
dframe
# Out:
#             Brand      Model  Year  Mileage_kmpl    Engine_CC  Horsepower  \
# 0          Toyota      Camry  2001     19.615852  1396.560379         NaN
# 1         Hyundai        i20  2012     19.478608  1130.771005  137.021719
# 2        Mahindra     Bolero  2008     17.469920  1766.466250  142.902960
# 3             BMW         X1  2015     21.295421          NaN   49.782079
# 4           Honda      Civic  2022     18.326833  1239.334935  121.505993
# ...           ...        ...   ...           ...          ...         ...
# 1004995    Nissan    Magnite  2022     12.256422  1773.657889  117.574596
# 1004996     Honda      Amaze  2005           NaN  1705.773023   99.643689
# 1004997     Skoda    Octavia  2018     21.665335  1447.159515         NaN
# 1004998       BMW         X3  2010     17.852635  2179.906631         NaN
# 1004999      Ford  Endeavour  2010     20.839002   800.000000   11.857082
#
#         Fuel_Type Transmission Owner_Type  Color       City  Kms_Driven  \
# ...

# %%
dframe.columns
# Out:
# Index(['Brand', 'Model', 'Year', 'Mileage_kmpl', 'Engine_CC', 'Horsepower',
#        'Fuel_Type', 'Transmission', 'Owner_Type', 'Color', 'City',
#        'Kms_Driven', 'Insurance_Valid', 'Service_History', 'Accidents',
#        'Tax_Paid', 'Number_of_Doors', 'Seats', 'Registration_Age', 'Price'],
#       dtype='object')

# %%
dframe['Brand']=='BMW'
# Out:
# 0          False
# 1          False
# 2          False
# 3           True
# 4          False
#            ...
# 1004995    False
# 1004996    False
# 1004997    False
# 1004998     True
# 1004999    False
# Name: Brand, Length: 1005000, dtype: bool

# %%
fi=dframe['Brand']=='BMW'
dframe.loc[fi]
# Out:
#         Brand     Model  Year  Mileage_kmpl    Engine_CC  Horsepower  \
# 3         BMW        X1  2008     21.295421          NaN   49.782079
# 20        BMW        X3  2008     19.570696          NaN  154.373826
# 24        BMW  3 Series  2008     17.822940  1089.912293   78.973454
# 27        BMW        X3  2008     12.237087  1384.376887   80.199592
# 48        BMW        X3  2008     22.630736  1889.931287  197.427894
# ...       ...       ...   ...           ...          ...         ...
# 1004928   BMW        X3  2008     21.063811  1663.687534  145.562860
# 1004956   BMW        X1  2008     16.703533  1563.927986  103.122579
# 1004968   BMW        X3  2008           NaN  1994.409284  152.778428
# 1004985   BMW        X1  2008     21.410263  1672.277752  164.591353
# 1004998   BMW        X3  2008     17.852635  2179.906631         NaN
#
#         Fuel_Type Transmission Owner_Type   Color       City  Kms_Driven  \
# ...

# %%
filt=dframe['Brand']=='BMW'
dframe.loc[filt].head(10)
# Out:
#     Brand     Model  Year  Mileage_kmpl    Engine_CC  Horsepower Fuel_Type  \
# 3     BMW        X1  2008     21.295421          NaN   49.782079       NaN
# 20    BMW        X3  2008     19.570696          NaN  154.373826    Petrol
# 24    BMW  3 Series  2008     17.822940  1089.912293   78.973454    Petrol
# 27    BMW        X3  2008     12.237087  1384.376887   80.199592    Diesel
# 48    BMW        X3  2008     22.630736  1889.931287  197.427894       CNG
# 83    BMW        X3  2008     18.962149  1911.992909  163.050097    Petrol
# 92    BMW  3 Series  2008     21.492230  1288.822304  116.269259    Petrol
# 112   BMW        X3  2008           NaN  1137.820241   72.996406    Diesel
# 124   BMW  3 Series  2008     13.527478  1545.032759   99.649106       NaN
# 127   BMW        X1  2008     16.942514  1177.315713   96.661029    Diesel
#
#     Transmission Owner_Type   Color       City  Kms_Driven  Insurance_Valid  \
# ...

# %%
filt=((dframe['City']=='Hyderabad') & (dframe['Color']=='Blue') &(dframe['Brand']=='BMW'))
wdf=dframe.loc[filt].sort_index(ascending=True).head(20)
wdf.to_csv("/content/car_hyd_bmw.csv")

# %%
import pandas as pd
students={
    'Name':['SKC','NA','GJ','SK'],
    'Rollno':[123,124,125,126],
    'Branch':['CSM','CSE','ECE','EEE'],
    'City':['Knl','TS','EG','WRNGL']
}
print(students)
dframe=pd.DataFrame(students)
dframe
dframe.shape
dframe['Branch']
dframe.loc[0:2,['City','Branch']]
# Out:
# {'Name': ['SKC', 'NA', 'GJ', 'SK'], 'Rollno': [123, 124, 125, 126], 'Branch': ['CSM', 'CSE', 'ECE', 'EEE'], 'City': ['Knl', 'TS', 'EG', 'WRNGL']}
#   City Branch
# 0  Knl    CSM
# 1   TS    CSE
# 2   EG    ECE
